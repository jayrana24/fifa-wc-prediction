# %%
import pandas as pd

df_games = pd.read_csv('/home/user1/project/fifa_prediction/results.csv')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
print(df_games.shape)
df_games.head()
# Out:
# (49477, 9)
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df_games.tail()
# Out:
#              date home_team   away_team  home_score  away_score  \
# 49472  2026-06-27    Jordan   Argentina         NaN         NaN
# 49473  2026-06-27  Colombia    Portugal         NaN         NaN
# 49474  2026-06-27  DR Congo  Uzbekistan         NaN         NaN
# 49475  2026-06-27    Panama     England         NaN         NaN
# 49476  2026-06-27   Croatia       Ghana         NaN         NaN
#
#            tournament             city        country  neutral
# 49472  FIFA World Cup        Arlington  United States     True
# 49473  FIFA World Cup    Miami Gardens  United States     True
# 49474  FIFA World Cup          Atlanta  United States     True
# 49475  FIFA World Cup  East Rutherford  United States     True
# 49476  FIFA World Cup     Philadelphia  United States     True

# %%
historical_matches = df_games[df_games['home_score'].notna()].copy()
wc2026_fixtures = df_games[df_games['home_score'].isna()].copy()

# %%
print(historical_matches.shape)
historical_matches.head()
# Out:
# (49425, 9)
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
print(wc2026_fixtures.shape)
wc2026_fixtures.head()
# Out:
# (52, 9)
#              date       home_team     away_team  home_score  away_score  \
# 49425  2026-06-17        Portugal      DR Congo         NaN         NaN
# 49426  2026-06-17      Uzbekistan      Colombia         NaN         NaN
# 49427  2026-06-17         England       Croatia         NaN         NaN
# 49428  2026-06-17           Ghana        Panama         NaN         NaN
# 49429  2026-06-18  Czech Republic  South Africa         NaN         NaN
#
#            tournament         city        country  neutral
# 49425  FIFA World Cup      Houston  United States     True
# 49426  FIFA World Cup  Mexico City         Mexico     True
# 49427  FIFA World Cup    Arlington  United States     True
# 49428  FIFA World Cup      Toronto         Canada     True
# 49429  FIFA World Cup      Atlanta  United States     True

# %%
historical_matches.to_csv('/home/user1/project/fifa_prediction/historical_matches.csv', index=False)
wc2026_fixtures.to_csv('/home/user1/project/fifa_prediction/wc2026_fixtures.csv', index=False)

print(f"Historical matches: {len(historical_matches)}")
print(f"WC2026 fixtures: {len(wc2026_fixtures)}")
# Out:
# Historical matches: 49425
# WC2026 fixtures: 52
